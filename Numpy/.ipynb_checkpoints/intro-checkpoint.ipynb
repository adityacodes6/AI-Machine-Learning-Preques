# %%
import numpy as np

# %%
print(np.__version__) # current version
# Out:
# 1.26.4

# %%
my_list = [1,2,3,4] 

my_list = my_list * 2
my_list
# Out:
# [1, 2, 3, 4, 1, 2, 3, 4]

# %%
arr = np.array([1,2,3,4])
arr = arr * 2

print(arr)
print(type(arr))
# Out:
# [2 4 6 8]
# <class 'numpy.ndarray'>

# %%
# scalar and vector opr
