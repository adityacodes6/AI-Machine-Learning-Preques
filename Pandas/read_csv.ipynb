# %%
import pandas as pd

# %%
df = pd.read_csv("students.csv")
df
# Out:
#       id      Name  Gender  Age Section  Science  English  History  Maths  \
# 0      1   Bronnie  Female   13       C       21       81       62     49
# 1      2    Lemmie    Male   15       B       29       41       17     40
# 2      3     Danya  Female   14       C       12       87       16     96
# 3      4     Denna  Female   14       B       15       53       82     33
# 4      5   Jocelin    Male   14       A       43        6        3     21
# ..   ...       ...     ...  ...     ...      ...      ...      ...    ...
# 245  246    Nickie    Male   13       C       28       15       25     10
# 246  247       Rog  Female   13       B        1        4       68     65
# 247  248      Kaia    Male   15       B       93       48       82     44
# 248  249      Anni  Female   14       B       35       73       66     59
# 249  250  Fernande    Male   15       B       50        8       80     78
#
#      Total Result Grade
# 0      213   Pass     B
# 1      127   Fail     D
# ...

# %%
# print all data use this method

print(df.to_string())
# Out:
#       id          Name  Gender  Age Section  Science  English  History  Maths  Total Result Grade
# 0      1       Bronnie  Female   13       C       21       81       62     49    213   Pass     B
# 1      2        Lemmie    Male   15       B       29       41       17     40    127   Fail     D
# 2      3         Danya  Female   14       C       12       87       16     96    211   Pass     B
# 3      4         Denna  Female   14       B       15       53       82     33    183   Pass     C
# 4      5       Jocelin    Male   14       A       43        6        3     21     73   Fail  Fail
# 5      6       Malissa  Female   14       C       98       51       85     76    310   Pass     A
# 6      7       Ichabod  Female   14       B       38       74       54     60    226   Pass     B
# 7      8      Beverlie    Male   14       B       25       51       41     80    197   Pass     C
# 8      9       Corrine    Male   15       A       39       16       22     49    126   Fail     D
# ...

# %%
df[df == "Pass"]
df["Result"]
# Out:
# 0      Pass
# 1      Fail
# 2      Pass
# 3      Pass
# 4      Fail
#        ...
# 245    Fail
# 246    Fail
# 247    Pass
# 248    Pass
# 249    Pass
# Name: Result, Length: 250, dtype: object
