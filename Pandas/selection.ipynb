# %%
import pandas as pd

# %%
df = pd.read_csv("students.csv", index_col = "Name")
df
# Out:
#            id  Gender  Age Section  Science  English  History  Maths  Total  \
# Name
# Bronnie     1  Female   13       C       21       81       62     49    213
# Lemmie      2    Male   15       B       29       41       17     40    127
# Danya       3  Female   14       C       12       87       16     96    211
# Denna       4  Female   14       B       15       53       82     33    183
# Jocelin     5    Male   14       A       43        6        3     21     73
# ...       ...     ...  ...     ...      ...      ...      ...    ...    ...
# Nickie    246    Male   13       C       28       15       25     10     78
# Rog       247  Female   13       B        1        4       68     65    138
# Kaia      248    Male   15       B       93       48       82     44    267
# Anni      249  Female   14       B       35       73       66     59    233
# Fernande  250    Male   15       B       50        8       80     78    216
#
#          Result Grade
# Name
# ...

# %%
# selection by column

print(df["Name"].to_string())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 3
#       1 # selection by column
# ----> 3 print(df["Name"].to_string())
#
# ...

# %%
# grade

# print(df["Grade"])
# print(df["Total"])
print(df[["Name", "Grade", "Result"]].to_string())
# Out:
#              Name Grade Result
# 0         Bronnie     B   Pass
# 1          Lemmie     D   Fail
# 2           Danya     B   Pass
# 3           Denna     C   Pass
# 4         Jocelin  Fail   Fail
# 5         Malissa     A   Pass
# 6         Ichabod     B   Pass
# 7        Beverlie     C   Pass
# 8         Corrine     D   Fail
# 9            Tate     D   Fail
# 10           Dunn     A   Pass
# 11        Valaria     C   Pass
# 12        Merrick     A   Pass
# 13         Gracie     A   Pass
# 14          Missy     A   Pass
# 15       Gilberta     B   Pass
# 16          Peggy     B   Pass
# 17           Dory     D   Fail
# 18        Opalina     A   Pass
# 19         Ashlan  Fail   Fail
# 20          Amery     A   Pass
# 21        Benoite     C   Pass
# 22          Merle     D   Fail
# 23          Valma     A   Pass
# 24           Jone     C   Pass
# 25            Rae     C   Pass
# 26       Charmine     A   Pass
# 27          Hanan     A   Pass
# 28         Adrian     C   Pass
# ...

# %%
# selection by rows

# print(df.loc["Tate"])
print(df.loc["Kaia"])
# Out:
# id          248
# Gender     Male
# Age          15
# Section       B
# Science      93
# English      48
# History      82
# Maths        44
# Total       267
# Result     Pass
# Grade         A
# Name: Kaia, dtype: object

# %%
print(df.loc["Kaia", ["Result", "Grade"]])
# Out:
# Result    Pass
# Grade        A
# Name: Kaia, dtype: object

# %%
print(df.iloc[0:11])
# Out:
#           id  Gender  Age Section  Science  English  History  Maths  Total  \
# Name
# Bronnie    1  Female   13       C       21       81       62     49    213
# Lemmie     2    Male   15       B       29       41       17     40    127
# Danya      3  Female   14       C       12       87       16     96    211
# Denna      4  Female   14       B       15       53       82     33    183
# Jocelin    5    Male   14       A       43        6        3     21     73
# Malissa    6  Female   14       C       98       51       85     76    310
# Ichabod    7  Female   14       B       38       74       54     60    226
# Beverlie   8    Male   14       B       25       51       41     80    197
# Corrine    9    Male   15       A       39       16       22     49    126
# Tate      10    Male   15       C       35       25       37     27    124
# Dunn      11    Male   15       C      100       93       87     81    361
#
#          Result Grade
# Name
# Bronnie    Pass     B
# ...

# %%
student = input("Enter a student Name:" )

try:
    print(df.loc[student])
except keyError:
    print(f"{student} not found")
# Out:
# Enter a student Name: Bronnie
# id              1
# Gender     Female
# Age            13
# Section         C
# Science        21
# English        81
# History        62
# Maths          49
# Total         213
# Result       Pass
# Grade           B
# Name: Bronnie, dtype: object
