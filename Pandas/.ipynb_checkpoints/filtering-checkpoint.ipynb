# %%
import pandas as pd

# %%
df = pd.read_csv("students.csv")
df
# Out:
#       id      Name  Gender  Age Section  Science  English  History  Maths  \
# 0      1   Bronnie  Female   13       C       21       81       62     49
# 1      2    Lemmie    Male   15       B       29       41       17     40
# 2      3     Danya  Female   14       C       12       87       16     96
# 3      4     Denna  Female   14       B       15       53       82     33
# 4      5   Jocelin    Male   14       A       43        6        3     21
# ..   ...       ...     ...  ...     ...      ...      ...      ...    ...
# 245  246    Nickie    Male   13       C       28       15       25     10
# 246  247       Rog  Female   13       B        1        4       68     65
# 247  248      Kaia    Male   15       B       93       48       82     44
# 248  249      Anni  Female   14       B       35       73       66     59
# 249  250  Fernande    Male   15       B       50        8       80     78
#
#      Total Result Grade
# 0      213   Pass     B
# 1      127   Fail     D
# ...

# %%
# filternig means keeping the rows that match a condition

# %%
pass_student = df[df["Total"] >= 200] # greater than 200
pass_student
# Out:
#       id      Name  Gender  Age Section  Science  English  History  Maths  \
# 0      1   Bronnie  Female   13       C       21       81       62     49
# 2      3     Danya  Female   14       C       12       87       16     96
# 5      6   Malissa  Female   14       C       98       51       85     76
# 6      7   Ichabod  Female   14       B       38       74       54     60
# 10    11      Dunn    Male   15       C      100       93       87     81
# ..   ...       ...     ...  ...     ...      ...      ...      ...    ...
# 241  242     Janey    Male   15       C        3       49       67     96
# 243  244   Domingo    Male   13       C       95       63       65     71
# 247  248      Kaia    Male   15       B       93       48       82     44
# 248  249      Anni  Female   14       B       35       73       66     59
# 249  250  Fernande    Male   15       B       50        8       80     78
#
#      Total Result Grade
# 0      213   Pass     B
# 2      211   Pass     B
# ...

# %%
# passs students 
pass_student = df[df["Result"] == "Pass"]
pass_student
# Out:
#       id      Name  Gender  Age Section  Science  English  History  Maths  \
# 0      1   Bronnie  Female   13       C       21       81       62     49
# 2      3     Danya  Female   14       C       12       87       16     96
# 3      4     Denna  Female   14       B       15       53       82     33
# 5      6   Malissa  Female   14       C       98       51       85     76
# 6      7   Ichabod  Female   14       B       38       74       54     60
# ..   ...       ...     ...  ...     ...      ...      ...      ...    ...
# 241  242     Janey    Male   15       C        3       49       67     96
# 243  244   Domingo    Male   13       C       95       63       65     71
# 247  248      Kaia    Male   15       B       93       48       82     44
# 248  249      Anni  Female   14       B       35       73       66     59
# 249  250  Fernande    Male   15       B       50        8       80     78
#
#      Total Result Grade
# 0      213   Pass     B
# 2      211   Pass     B
# ...

# %%
# fail students
fail_students = df[df["Result"] == "Fail"]
fail_students
# Out:
#       id          Name  Gender  Age Section  Science  English  History  Maths  \
# 1      2        Lemmie    Male   15       B       29       41       17     40
# 4      5       Jocelin    Male   14       A       43        6        3     21
# 8      9       Corrine    Male   15       A       39       16       22     49
# 9     10          Tate    Male   15       C       35       25       37     27
# 17    18          Dory  Female   13       B        5       89       25     23
# 19    20        Ashlan    Male   13       B       41        6       17      3
# 22    23         Merle  Female   13       C        5       83       19     39
# 31    32     Ekaterina  Female   15       B       17       36       45     27
# 33    34         Zarla  Female   15       B       54       18       46     17
# 42    43       Brandie    Male   15       B       43        2       17     78
# 57    58         Issie    Male   14       A       64        1       74      6
# ...

# %%
male_students = df[df["Gender"] == "Male"]
male_students
# Out:
#       id      Name Gender  Age Section  Science  English  History  Maths  \
# 1      2    Lemmie   Male   15       B       29       41       17     40
# 4      5   Jocelin   Male   14       A       43        6        3     21
# 7      8  Beverlie   Male   14       B       25       51       41     80
# 8      9   Corrine   Male   15       A       39       16       22     49
# 9     10      Tate   Male   15       C       35       25       37     27
# ..   ...       ...    ...  ...     ...      ...      ...      ...    ...
# 241  242     Janey   Male   15       C        3       49       67     96
# 243  244   Domingo   Male   13       C       95       63       65     71
# 245  246    Nickie   Male   13       C       28       15       25     10
# 247  248      Kaia   Male   15       B       93       48       82     44
# 249  250  Fernande   Male   15       B       50        8       80     78
#
#      Total Result Grade
# 1      127   Fail     D
# 4       73   Fail  Fail
# ...

# %%
female_students = df[df["Gender"] == "Female"]
female_students
# Out:
#       id      Name  Gender  Age Section  Science  English  History  Maths  \
# 0      1   Bronnie  Female   13       C       21       81       62     49
# 2      3     Danya  Female   14       C       12       87       16     96
# 3      4     Denna  Female   14       B       15       53       82     33
# 5      6   Malissa  Female   14       C       98       51       85     76
# 6      7   Ichabod  Female   14       B       38       74       54     60
# ..   ...       ...     ...  ...     ...      ...      ...      ...    ...
# 238  239    Ashlin  Female   14       A       49       47       19     55
# 242  243    Morrie  Female   13       B       17       24       41     21
# 244  245  Jesselyn  Female   15       C       11       53       15     13
# 246  247       Rog  Female   13       B        1        4       68     65
# 248  249      Anni  Female   14       B       35       73       66     59
#
#      Total Result Grade
# 0      213   Pass     B
# 2      211   Pass     B
# ...
