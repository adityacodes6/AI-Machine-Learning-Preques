# %%
import pandas as pd

# %%
# reduce set of values into a single summary value

# %%
df = pd.read_csv("students.csv")
df
# Out:
#       id      Name  Gender  Age Section  Science  English  History  Maths  \
# 0      1   Bronnie  Female   13       C       21       81       62     49
# 1      2    Lemmie    Male   15       B       29       41       17     40
# 2      3     Danya  Female   14       C       12       87       16     96
# 3      4     Denna  Female   14       B       15       53       82     33
# 4      5   Jocelin    Male   14       A       43        6        3     21
# ..   ...       ...     ...  ...     ...      ...      ...      ...    ...
# 245  246    Nickie    Male   13       C       28       15       25     10
# 246  247       Rog  Female   13       B        1        4       68     65
# 247  248      Kaia    Male   15       B       93       48       82     44
# 248  249      Anni  Female   14       B       35       73       66     59
# 249  250  Fernande    Male   15       B       50        8       80     78
#
#      Total Result Grade
# 0      213   Pass     B
# 1      127   Fail     D
# ...

# %%
# find the mean any columns that are numeric

# whole data frame
# df.mean(numeric_only= True)
# df.sum(numeric_only= True)
# df.min(numeric_only= True)
# df.max(numeric_only= True)
df.count() # no of valuse in each col
# Out:
# id         250
# Name       250
# Gender     250
# Age        250
# Section    250
# Science    250
# English    250
# History    250
# Maths      250
# Total      250
# Result     250
# Grade      250
# dtype: int64

# %%
# df["Total"].mean(numeric_only= True)
# df["Total"].sum(numeric_only= True)
# df["Total"].min(numeric_only= True)
# df["Total"].max(numeric_only= True)
df["Total"].count() # no of valuse in each col
# Out:
# 250

# %%
# group by

# %%
df
# Out:
#       id      Name  Gender  Age Section  Science  English  History  Maths  \
# 0      1   Bronnie  Female   13       C       21       81       62     49
# 1      2    Lemmie    Male   15       B       29       41       17     40
# 2      3     Danya  Female   14       C       12       87       16     96
# 3      4     Denna  Female   14       B       15       53       82     33
# 4      5   Jocelin    Male   14       A       43        6        3     21
# ..   ...       ...     ...  ...     ...      ...      ...      ...    ...
# 245  246    Nickie    Male   13       C       28       15       25     10
# 246  247       Rog  Female   13       B        1        4       68     65
# 247  248      Kaia    Male   15       B       93       48       82     44
# 248  249      Anni  Female   14       B       35       73       66     59
# 249  250  Fernande    Male   15       B       50        8       80     78
#
#      Total Result Grade
# 0      213   Pass     B
# 1      127   Fail     D
# ...

# %%
group = df.groupby("Gender")
print(group["Total"].mean())
# Out:
# Gender
# Female    202.618644
# Male      206.575758
# Name: Total, dtype: float64

# %%
print(group["Total"].sum())
# Out:
# Gender
# Female    23909
# Male      27268
# Name: Total, dtype: int64

# %%
print(group["Total"].min())
# Out:
# Gender
# Female    57
# Male      67
# Name: Total, dtype: int64

# %%
print(group["Total"].max())
# Out:
# Gender
# Female    347
# Male      361
# Name: Total, dtype: int64

# %%
print(group["Total"].count())
# Out:
# Gender
# Female    118
# Male      132
# Name: Total, dtype: int64
