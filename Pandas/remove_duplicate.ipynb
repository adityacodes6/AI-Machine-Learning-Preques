# %%
import pandas as pd

# %%
df = pd.read_csv("duplicates.csv")
df
# Out:
#     id      Name  Gender  Age Section  Science  English  History  Maths  \
# 0    1   Bronnie  Female   13       C       21       81       62     49
# 1    1   Bronnie  Female   13       C       21       81       62     49
# 2    3     Danya  Female   14       C       12       87       16     96
# 3    4     Denna  Female   14       B       15       53       82     33
# 4    5   Jocelin    Male   14       A       43        6        3     21
# 5    1   Bronnie  Female   13       C       21       81       62     49
# 6    7   Ichabod  Female   14       B       38       74       54     60
# 7    8  Beverlie    Male   14       B       25       51       41     80
# 8    8  Beverlie    Male   14       B       25       51       41     80
# 9   10      Tate    Male   15       C       35       25       37     27
# 10  11      Dunn    Male   15       C      100       93       87     81
# 11  12   Valaria    Male   13       B       19        5       78     76
# ...

# %%
# show duplicates
df = df.duplicated()
df
# Out:
# 0     False
# 1      True
# 2     False
# 3     False
# 4     False
# 5      True
# 6     False
# 7     False
# 8      True
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24     True
# dtype: bool

# %%
# drop duplicate values
df = df.drop_duplicates()
df
# Out:
# 0    False
# 1     True
# dtype: bool
