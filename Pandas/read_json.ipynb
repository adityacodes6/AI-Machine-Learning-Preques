# %%
import pandas as pd

# %%
df = pd.read_json("data.json")
df
# Out:
#    id    Name  Age
# 0   1  Aditya   19
# 1   2    Baby   26
# 2   3  Deobra   28
# 3   4  Martha   26
# 4   5   Spidy   24
# 5   6     Sam   21
